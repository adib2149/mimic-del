# %% [markdown]
# - [X] see sql5 file
# - [X] variable match and selection
# - [ ] define inclusion-exclusion criteria
# - [ ] define target trial (cite hernan)

# %% [markdown]
# # All the features (Slide 11, page 14)
#
# ### Demographic:
# - Gender *
# - Age (IQR) *
# - Ethnicity (Race: White, black, multiple or others) *
# ### Diseases:
# - Other diseases (icd9 codes) *
# - Surgery *
# - Pneumonia *
# - Infection
# - Sepsis (diagnosis at admission) *
# - Dementia *
# - Alzheimer's *
# - Depression *
# - Anxiety *
# - Coma (drug induced, miscellaneous, combination)
# - Metabolic acidosis
# - Respiratory failure
# - ARDS (diagnosis at admission)
# - Airway Protection (diagnosis at admission)
# - Chronic Obstructive Pulmonary Disease, Asthma, or other pulmonary disorder (diagnosis at admission)
# - Chronic heart failure, myocardial infarction, or arrhythmia (diagnosis at admission)
# - Cirrhosis or Liver failure (diagnosis at admission)
# - Other (diagnosis at admission)
# ### Drugs:
# - List of drugs prescribed *
# - Received APD treatment - no (%) (before admission, before admission and randomization)
# - APD prescribed *
# - Distinct APD categories *
# ### Admission events:
# - Admission category (surgical, medical, trauma, neurology/neurosurgical)
# - Length of stay *
# - Mechanical ventilation ^*
# - Mechanical ventilation hours ^ *
# - Sedatives use (yes)
# - Morphine use (mg/day)
# - Urea concentration (mmol/L)
# - Urgent admission (%)
# - Hx of cognitive impairment
# - Hx of ETOH use
# - MAP (mean arterial blood pressure) at the time of ICU admission
# - Use of Corticosteroids
# - BUN (blood urea nitrogen) at the of ICU admission
# - Admitted to Surgical ICU - no (%)
# - Received assisted ventilation before randomization - no (%) Invasive and Noninvasive
# - Shock before randomization - no (%)
# - Median no of days from ICU admission to randomization - (IQR)
# ### Evaluation:
# - APACHE-II score (Acute Physiology & Chronic Health Evaluation) (at randomization)
#  - APSIII in place of Apache score https://github.com/MIT-LCP/mimic-code/issues/653
# - Median Short-form IQCODE score (IQR)
# - Median Charlson Comorbidity Index Score (IQR)
# - Median SOFA score at randomization
# - Hyperactive Delirium at Randomization- no (%)
# - Hypoactive Delirium at Randomization - no (%)
# ### Outcomes:
# - Death in hospital *
# - Death in one year *

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("delirium_data.csv")

# %%
data.shape
# Out:
# (1671, 30)

# %%
data.columns
# Out:
# Index(['subject_id', 'gender', 'age', 'ethnicity', 'hadm_id', 'icustay_id',
#        'los_days', 'icd9_codes', 'sofa', 'apsiii', 'mechvent_starttime',
#        'mechvent', 'mechvent_duration_hours', 'drugs', 'dist_cat_count',
#        'drug_categories', 'had_surgery', 'had_pneu', 'sepsis', 'dementia',
#        'alzheimers', 'depression', 'anxiety', 'death_hosp', 'death_one_year',
#        'drugstarttime', 'admittime', 'dischtime', 'deathtime',
#        'patient_deathtime'],
#       dtype='object')

# %% [markdown]
# # Deleted deathtime
# - ADMISSIONS.DEATHTIME (https://mimic.mit.edu/docs/iii/tables/admissions/)
#  - If applicable, DEATHTIME provides the time of in-hospital death for the patient. Note that DEATHTIME is only present if the patient died in-hospital, and is almost always the same as the patient’s DISCHTIME. However, there can be some discrepancies due to typographical errors.
#  - Use to find death in hospital
#
# - PATIENTS.DOD (https://mimic.mit.edu/docs/iii/tables/patients/)
#  - DOD is the date of death for the given patient. DOD_HOSP is the date of death as recorded in the hospital database. DOD_SSN is the date of death from the social security database. Note that DOD merged together DOD_HOSP and DOD_SSN, giving priority to DOD_HOSP if both were recorded.
#  - Real death time
#
# - Just DOD works fine.

# %%
data = data.drop('deathtime', 1)

data = data.rename(columns={
    "dist_cat_count": "drug_categories_distinct_count", 
    "gender": "sex", 
    "patient_deathtime": "deathtime", 
    "mechvent": "mechvent_count", 
    "had_surgery": "surgery", 
    "had_pneu": "pneumonia"})
# Out:
# /var/folders/k5/t6qrq2v55gxd80p9mdn45x9r8q8tz2/T/ipykernel_22719/3729729959.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('deathtime', 1)

# %%
data.shape
# Out:
# (1671, 29)

# %%
data.columns
# Out:
# Index(['subject_id', 'sex', 'age', 'ethnicity', 'hadm_id', 'icustay_id',
#        'los_days', 'icd9_codes', 'sofa', 'apsiii', 'mechvent_starttime',
#        'mechvent_count', 'mechvent_duration_hours', 'drugs',
#        'drug_categories_distinct_count', 'drug_categories', 'surgery',
#        'pneumonia', 'sepsis', 'dementia', 'alzheimers', 'depression',
#        'anxiety', 'death_hosp', 'death_one_year', 'drugstarttime', 'admittime',
#        'dischtime', 'deathtime'],
#       dtype='object')

# %%
data.sofa = data.sofa.fillna(-1)
data.apsiii = data.apsiii.fillna(-1)

# %%
data.icustay_id = data.icustay_id.fillna(0)
data.surgery = data.surgery.fillna(2)
data = data.astype({"icustay_id": int, "sofa": int, "apsiii": int, "sex": 'category', "ethnicity": 'category', "surgery": int})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subject_id                      1671 non-null   int64
#  1   sex                             1671 non-null   category
#  2   age                             1671 non-null   float64
#  3   ethnicity                       1671 non-null   category
#  4   hadm_id                         1671 non-null   int64
#  5   icustay_id                      1671 non-null   int64
#  6   los_days                        1665 non-null   float64
#  7   icd9_codes                      1671 non-null   object
#  8   sofa                            1671 non-null   int64
#  9   apsiii                          1671 non-null   int64
#  10  mechvent_starttime              854 non-null    object
#  11  mechvent_count                  1671 non-null   int64
#  12  mechvent_duration_hours         854 non-null    object
#  13  drugs                           1671 non-null   object
#  14  drug_categories_distinct_count  1671 non-null   int64
#  15  drug_categories                 1671 non-null   object
#  16  surgery                         1671 non-null   int64
#  17  pneumonia                       1671 non-null   int64
#  18  sepsis                          1671 non-null   int64
#  19  dementia                        1671 non-null   int64
#  20  alzheimers                      1671 non-null   int64
#  21  depression                      1671 non-null   int64
#  22  anxiety                         1671 non-null   int64
#  23  death_hosp                      1671 non-null   int64
#  24  death_one_year                  1671 non-null   int64
#  25  drugstarttime                   1665 non-null   object
#  26  admittime                       1671 non-null   object
#  27  dischtime                       1671 non-null   object
#  28  deathtime                       849 non-null    object
# dtypes: category(2), float64(2), int64(16), object(9)
# memory usage: 357.2+ KB

# %%
data.sample(10)
# Out:
#       subject_id sex     age               ethnicity  hadm_id  icustay_id  \
# 439        22437   M  300.00                   WHITE   111823      253867
# 566        27561   F   77.42  BLACK/AFRICAN AMERICAN   153158      205063
# 1127       64191   M   69.69                   WHITE   186864      252380
# 1000       55730   M   62.02                   WHITE   195438      245211
# 1397       81412   F   88.59                   WHITE   193352      278624
# 306        15358   M   57.62                   WHITE   105688      285673
# 1077       61144   F   51.83                   WHITE   187912      280981
# 1347       77471   M   26.52       ASIAN - CAMBODIAN   112557      269077
# 1128       64357   M   80.48                   WHITE   197694      272943
# 909        50404   M   29.87                   WHITE   110630      228881
#
#       los_days                                         icd9_codes  sofa  \
# 439     2.9688  42789: Cardiac dysrhythmias NEC\n7210: Cervica...     4
# 566     4.8398  0389: Septicemia NOS\n4280: CHF NOS\n486: Pneu...     8
# 1127    4.8505  0389: Septicemia NOS\n78552: Septic shock\n410...     9
# 1000   23.9861  430: Subarachnoid hemorrhage\n74781: Cerebrova...     2
# 1397    4.6487  47832: Vocal paral unilat total\n5070: Food/vo...     2
# 306     0.7914  5990: Urin tract infection NOS\n99831: Disrup ...     2
# 1077    4.9400  8082: Fracture of pubis-closed\n51851: Ac resp...     2
# 1347    0.3669  23875: Myelodysplastic synd NOS\n4940: Bronchi...     4
# 1128    1.6159  5570: Ac vasc insuff intestine\n5856: End stag...     6
# 909    12.1507  04119: Other staphylococcus\n99663: React-nerv...     0
#
#       apsiii   mechvent_starttime  mechvent_count  \
# 439       55                  NaN               0
# 566       99                  NaN               0
# 1127      45                  NaN               0
# 1000      20  2113-03-29 18:00:00               2
# 1397      40                  NaN               0
# 306       22                  NaN               0
# 1077      33  2189-07-08 22:00:00               5
# 1347      28                  NaN               0
# 1128      47                  NaN               0
# 909       22  2110-10-05 09:00:00               1
#
#                                 mechvent_duration_hours  \
# 439                                                 NaN
# 566                                                 NaN
# 1127                                                NaN
# 1000            19.2500000000000000, 1.3333333333333333
# 1397                                                NaN
# 306                                                 NaN
# 1077  36.2500000000000000, 7.0000000000000000, 16.33...
# 1347                                                NaN
# 1128                                                NaN
# 909                                168.5000000000000000
#
#                                                   drugs  \
# 439                                             No drug
# 566                                             No drug
# 1127  Quetiapine Fumarate\nHaloperidol\nHaloperidol\...
# 1000  Quetiapine Fumarate\nQuetiapine Fumarate\nQuet...
# 1397                                            No drug
# 306                  Prochlorperazine\nProchlorperazine
# 1077  Haloperidol\nQuetiapine Fumarate\nHaloperidol\...
# 1347                                            No drug
# 1128  Haloperidol\nHaloperidol\nHaloperidol\nQuetiap...
# 909   Prochlorperazine\nProchlorperazine\nQuetiapine...
#
#       drug_categories_distinct_count                      drug_categories  \
# 439                                0                              NO DRUG
# 566                                0                              NO DRUG
# 1127                               3  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE
# 1000                               1                           QUETIAPINE
# 1397                               0                              NO DRUG
# 306                                1                     PROCHLORPERAZINE
# 1077                               2              HALOPERIDOL\nQUETIAPINE
# 1347                               0                              NO DRUG
# 1128                               2              HALOPERIDOL\nQUETIAPINE
# 909                                2         PROCHLORPERAZINE\nQUETIAPINE
#
#       surgery  pneumonia  sepsis  dementia  alzheimers  depression  anxiety  \
# 439         2          0       0         0           0           0        0
# 566         1          1       1         0           0           0        0
# 1127        0          0       1         0           0           0        0
# 1000        1          0       0         0           0           0        0
# 1397        0          0       0         0           0           0        0
# 306         0          1       0         0           0           0        0
# 1077        1          0       0         0           0           0        0
# 1347        0          0       1         0           0           0        0
# 1128        0          0       0         0           0           0        0
# 909         1          0       1         0           0           0        0
#
#       death_hosp  death_one_year        drugstarttime            admittime  \
# 439            0               1  2179-11-25 19:52:00  2179-11-25 19:50:00
# 566            0               0  2161-07-01 22:30:08  2161-07-01 20:08:00
# 1127           0               0  2102-04-21 22:09:03  2102-04-21 22:08:00
# 1000           0               0  2113-03-29 16:16:11  2113-03-29 16:15:00
# 1397           0               1  2190-07-10 23:53:01  2190-07-10 23:51:00
# 306            0               1  2142-05-08 23:06:18  2142-05-07 14:00:00
# 1077           0               0  2189-07-08 19:40:19  2189-07-08 19:39:00
# 1347           0               1  2138-04-02 16:02:23  2138-03-29 12:43:00
# 1128           0               1  2105-01-03 20:03:21  2105-01-02 07:15:00
# 909            0               0  2110-10-01 17:07:49  2110-09-21 22:40:00
#
#                 dischtime            deathtime
# 439   2179-12-03 13:33:00  2179-12-31 00:00:00
# 566   2161-07-09 17:30:00                  NaN
# 1127  2102-05-03 16:42:00                  NaN
# 1000  2113-04-25 17:37:00                  NaN
# 1397  2190-07-22 15:15:00  2190-07-27 00:00:00
# 306   2142-07-14 15:50:00  2142-08-25 00:00:00
# 1077  2189-07-18 12:50:00                  NaN
# 1347  2138-04-11 14:45:00  2138-08-19 00:00:00
# 1128  2105-01-09 14:50:00  2105-08-07 00:00:00
# 909   2110-10-25 15:48:00                  NaN

# %% [markdown]
# # Checking for unique values and resolving if necessary

# %%
print(len(data.subject_id.unique()))
print(len(data.hadm_id.unique()))
print(len(data.icustay_id.unique()))
# Out:
# 1398
# 1445
# 1666

# %%
print("number of cases:", data[data.icustay_id.duplicated(keep=False)].shape)
data[data.icustay_id.duplicated(keep=False)]
# Out:
# number of cases: (6, 29)
#       subject_id sex    age               ethnicity  hadm_id  icustay_id  \
# 82          3734   F  57.12                   WHITE   154629           0
# 144         6537   F  82.79                   WHITE   152603           0
# 178         8450   M  79.10                   WHITE   157731           0
# 203         9795   M  77.68  BLACK/AFRICAN AMERICAN   182522           0
# 300        15047   F  73.89                   WHITE   137209           0
# 1295       75054   M  48.46                   WHITE   170546           0
#
#       los_days                                         icd9_codes  sofa  \
# 82         NaN  25070: DMII circ nt st uncntrld\n44024: Ath ex...    -1
# 144        NaN  3485: Cerebral edema\n1912: Mal neo temporal l...    -1
# 178        NaN  4414: Abdom aortic aneurysm\n4422: Iliac arter...    -1
# 203        NaN  99665: React-oth genitourin dev\n6084: Male ge...    -1
# 300        NaN  57451: Choledochlith NOS w obst\n99679: Comp-i...    -1
# 1295       NaN  73819: Oth spcf deformity head\n2930: Delirium...    -1
#
#       apsiii mechvent_starttime  mechvent_count mechvent_duration_hours  \
# 82        -1                NaN               0                     NaN
# 144       -1                NaN               0                     NaN
# 178       -1                NaN               0                     NaN
# 203       -1                NaN               0                     NaN
# 300       -1                NaN               0                     NaN
# 1295      -1                NaN               0                     NaN
#
#                                                   drugs  \
# 82                                              No drug
# 144   Quetiapine Fumarate\nQuetiapine Fumarate\nOlan...
# 178                                         Haloperidol
# 203   Haloperidol\nHaloperidol\nHaloperidol\nHaloper...
# 300                                             No drug
# 1295  Haloperidol\nProchlorperazine\nQuetiapine Fuma...
#
#       drug_categories_distinct_count  \
# 82                                 0
# 144                                2
# 178                                1
# 203                                1
# 300                                0
# 1295                               4
#
#                                         drug_categories  surgery  pneumonia  \
# 82                                              NO DRUG        2          0
# 144                              OLANZAPINE\nQUETIAPINE        1          0
# 178                                         HALOPERIDOL        0          0
# 203                                         HALOPERIDOL        0          0
# 300                                             NO DRUG        2          0
# 1295  HALOPERIDOL\nPROCHLORPERAZINE\nQUETIAPINE\nZIP...        1          0
#
#       sepsis  dementia  alzheimers  depression  anxiety  death_hosp  \
# 82         0         0           0           0        0           0
# 144        0         0           0           0        0           0
# 178        0         0           0           0        0           0
# 203        0         0           0           0        0           0
# 300        0         0           0           0        0           0
# 1295       0         0           0           0        0           0
#
#       death_one_year drugstarttime            admittime            dischtime  \
# 82                 0           NaN  2110-08-26 00:08:00  2110-08-30 16:36:00
# 144                1           NaN  2128-07-30 23:20:00  2128-08-05 14:00:00
# 178                0           NaN  2112-09-12 15:48:00  2112-09-19 16:11:00
# 203                0           NaN  2105-10-26 21:57:00  2105-11-03 15:24:00
# 300                0           NaN  2126-04-03 08:00:00  2126-04-09 11:53:00
# 1295               0           NaN  2159-12-12 12:15:00  2159-12-17 21:05:00
#
#                 deathtime
# 82    2111-12-04 00:00:00
# 144   2128-09-21 00:00:00
# 178                   NaN
# 203   2109-04-26 00:00:00
# 300   2127-06-30 00:00:00
# 1295                  NaN

# %% [markdown]
# Seems like they are six unique icu stay case, just with icustay_id missing, so we can ignore this issue now.

# %%
print("number of cases:", data[data.hadm_id.duplicated(keep=False)].shape)
data[data.hadm_id.duplicated(keep=False)].head(5)
# Out:
# number of cases: (412, 29)
#    subject_id sex    age ethnicity  hadm_id  icustay_id  los_days  \
# 1         214   M  63.44     WHITE   197273      200066    2.7044
# 2         214   M  63.44     WHITE   197273      255525    3.0368
# 3         214   M  63.44     WHITE   197273      241941    5.5964
# 4         223   M  67.51     WHITE   105694      255617   15.8837
# 5         223   M  67.51     WHITE   105694      231395    4.0629
#
#                                           icd9_codes  sofa  apsiii  \
# 1  41071: Subendo infarct, initial\n4280: CHF NOS...     6      58
# 2  41071: Subendo infarct, initial\n4280: CHF NOS...     4      49
# 3  41071: Subendo infarct, initial\n4280: CHF NOS...     6      73
# 4  0389: Septicemia NOS\n41021: AMI inferolateral...     7      48
# 5  0389: Septicemia NOS\n41021: AMI inferolateral...     3      33
#
#     mechvent_starttime  mechvent_count  \
# 1                  NaN               0
# 2  2188-10-24 16:40:00               1
# 3                  NaN               0
# 4  2157-05-01 06:00:00               5
# 5  2157-06-01 15:55:00               1
#
#                              mechvent_duration_hours  \
# 1                                                NaN
# 2                                 3.3333333333333333
# 3                                                NaN
# 4  28.0000000000000000, 21.7500000000000000, 20.0...
# 5                                11.5000000000000000
#
#                                                drugs  \
# 1  Haloperidol\nOlanzapine (Disintergrating Table...
# 2  Haloperidol\nOlanzapine (Disintergrating Table...
# 3  Haloperidol\nOlanzapine (Disintergrating Table...
# 4  Haloperidol\nHaloperidol\nHaloperidol\nHaloper...
# 5  Haloperidol\nHaloperidol\nHaloperidol\nHaloper...
#
#    drug_categories_distinct_count  \
# 1                               4
# 2                               4
# 3                               4
# 4                               2
# 5                               2
#
#                                     drug_categories  surgery  pneumonia  \
# 1  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 2  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 3  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 4                           HALOPERIDOL\nOLANZAPINE        1          1
# 5                           HALOPERIDOL\nOLANZAPINE        1          1
#
#    sepsis  dementia  alzheimers  depression  anxiety  death_hosp  \
# 1       0         0           0           0        0           0
# 2       0         0           0           0        0           0
# 3       0         0           0           0        0           0
# 4       1         0           0           0        0           0
# 5       1         0           0           0        0           0
#
#    death_one_year        drugstarttime            admittime  \
# 1               0  2188-10-06 23:56:53  2188-10-06 23:56:00
# 2               0  2188-10-24 15:45:55  2188-10-06 23:56:00
# 3               0  2188-10-28 21:26:20  2188-10-06 23:56:00
# 4               0  2157-05-01 05:20:41  2157-05-01 05:19:00
# 5               0  2157-06-01 11:33:51  2157-05-01 05:19:00
#
#              dischtime            deathtime
# 1  2188-11-04 11:40:00  2195-07-13 00:00:00
# 2  2188-11-04 11:40:00  2195-07-13 00:00:00
# 3  2188-11-04 11:40:00  2195-07-13 00:00:00
# 4  2157-07-01 10:20:00                  NaN
# 5  2157-07-01 10:20:00                  NaN

# %%
temp = data[data.hadm_id.duplicated(keep=False)]
for i in temp.subject_id.unique():
    temp2 = temp[temp.subject_id == i]
    if (temp2.shape[0] != len(temp2.icustay_id.unique())): # check for unique icustay_id for each individual
        print(i)

# %% [markdown]
# They all have unique icustay_id, so treating as individual persons

# %%
print("number of cases:", data[data.subject_id.duplicated(keep=False)].shape)
data[data.subject_id.duplicated(keep=False)].head(5)
# Out:
# number of cases: (494, 29)
#    subject_id sex    age ethnicity  hadm_id  icustay_id  los_days  \
# 1         214   M  63.44     WHITE   197273      200066    2.7044
# 2         214   M  63.44     WHITE   197273      255525    3.0368
# 3         214   M  63.44     WHITE   197273      241941    5.5964
# 4         223   M  67.51     WHITE   105694      255617   15.8837
# 5         223   M  67.51     WHITE   105694      231395    4.0629
#
#                                           icd9_codes  sofa  apsiii  \
# 1  41071: Subendo infarct, initial\n4280: CHF NOS...     6      58
# 2  41071: Subendo infarct, initial\n4280: CHF NOS...     4      49
# 3  41071: Subendo infarct, initial\n4280: CHF NOS...     6      73
# 4  0389: Septicemia NOS\n41021: AMI inferolateral...     7      48
# 5  0389: Septicemia NOS\n41021: AMI inferolateral...     3      33
#
#     mechvent_starttime  mechvent_count  \
# 1                  NaN               0
# 2  2188-10-24 16:40:00               1
# 3                  NaN               0
# 4  2157-05-01 06:00:00               5
# 5  2157-06-01 15:55:00               1
#
#                              mechvent_duration_hours  \
# 1                                                NaN
# 2                                 3.3333333333333333
# 3                                                NaN
# 4  28.0000000000000000, 21.7500000000000000, 20.0...
# 5                                11.5000000000000000
#
#                                                drugs  \
# 1  Haloperidol\nOlanzapine (Disintergrating Table...
# 2  Haloperidol\nOlanzapine (Disintergrating Table...
# 3  Haloperidol\nOlanzapine (Disintergrating Table...
# 4  Haloperidol\nHaloperidol\nHaloperidol\nHaloper...
# 5  Haloperidol\nHaloperidol\nHaloperidol\nHaloper...
#
#    drug_categories_distinct_count  \
# 1                               4
# 2                               4
# 3                               4
# 4                               2
# 5                               2
#
#                                     drug_categories  surgery  pneumonia  \
# 1  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 2  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 3  HALOPERIDOL\nOLANZAPINE\nQUETIAPINE\nRISPERIDONE        0          0
# 4                           HALOPERIDOL\nOLANZAPINE        1          1
# 5                           HALOPERIDOL\nOLANZAPINE        1          1
#
#    sepsis  dementia  alzheimers  depression  anxiety  death_hosp  \
# 1       0         0           0           0        0           0
# 2       0         0           0           0        0           0
# 3       0         0           0           0        0           0
# 4       1         0           0           0        0           0
# 5       1         0           0           0        0           0
#
#    death_one_year        drugstarttime            admittime  \
# 1               0  2188-10-06 23:56:53  2188-10-06 23:56:00
# 2               0  2188-10-24 15:45:55  2188-10-06 23:56:00
# 3               0  2188-10-28 21:26:20  2188-10-06 23:56:00
# 4               0  2157-05-01 05:20:41  2157-05-01 05:19:00
# 5               0  2157-06-01 11:33:51  2157-05-01 05:19:00
#
#              dischtime            deathtime
# 1  2188-11-04 11:40:00  2195-07-13 00:00:00
# 2  2188-11-04 11:40:00  2195-07-13 00:00:00
# 3  2188-11-04 11:40:00  2195-07-13 00:00:00
# 4  2157-07-01 10:20:00                  NaN
# 5  2157-07-01 10:20:00                  NaN

# %% [markdown]
# # Explore other icd9 codes

# %%
# data[data.icd9_codes.str.contains("518")]
all_icd_codes = pd.DataFrame(columns = ["shortcode", "longcode", "name", "count"])
for i in data.index:
    codes = data.icd9_codes[i].split("\n")
    for c in codes:
        shortcode = c[0:3]
        longcode = c.split(":")[0]
        name = c.split(": ")[1]
        ind_for_data_entry = all_icd_codes[all_icd_codes.longcode == longcode]
        if (len(ind_for_data_entry) == 0):
            all_icd_codes = pd.concat([all_icd_codes, pd.DataFrame(data={"shortcode": shortcode, "longcode":longcode, "name":name, "count":1}, index=[0])], axis=0, ignore_index=True)
        else:
            all_icd_codes.at[ind_for_data_entry.index[0],"count"] += 1

# %%
all_icd_codes.shape
# Out:
# (2422, 4)

# %%
# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# - https://www.findacode.com/search/search.php
# - http://www.icd9data.com/2015/Volume1/
#
# - Other diseases (icd9 codes) *
# - Surgery *
# - Pneumonia *
# - Infection
# - Sepsis (diagnosis at admission) *
# - Dementia *
# - Alzheimer's *
# - Depression *
# - Anxiety *
# - (COMPLEX) Coma (drug induced, miscellaneous, combination) [use name.str search with coma]
# - Metabolic acidosis * [276.2]
# - (COMPLEX) Respiratory failure [518.51, 518.53, 518.81, 581.83, 581.84, 799.1]
# - (COMPLEX) ARDS (diagnosis at admission) [its complex since requires many other data, https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0257056]
# - Airway Protection * (diagnosis at admission) [496]
# - [490-496] Chronic Obstructive Pulmonary Disease, [493] Asthma, or [496] other pulmonary disorder (diagnosis at admission)
#  - COPD * [490-496]: a group of diseases that cause airflow blockage and breathing-related problems
# - [428] Chronic heart failure, [410] myocardial infarction, or [427] AF and arrhythmia (diagnosis at admission)
#  - heart issues *
# - [571] Cirrhosis or [570] Liver failure (diagnosis at admission)
#  - Liver issues *
# - Other (diagnosis at admission)

# %%
data[data.icd9_codes.str.contains("496: Chr airway obstruct NEC")].shape
# Out:
# (175, 29)

# %%
all_icd_codes[all_icd_codes.name.str.contains("sepsis")]
# Out:
#    shortcode longcode           name count
# 27       995    99592  Severe sepsis   305

# %%
data['met_acidosis'] = np.where(data.icd9_codes.str.contains("2764: Mixed acid-base bal dis"), 1, 0)
data['airway_obs'] = np.where(data.icd9_codes.str.contains("496: Chr airway obstruct NEC"), 1, 0)

copd_codes = ['490: Bronchitis NOS', '49121: Obs chr bronc w(ac) exac', 
              '4928: Emphysema NEC', '49392: Asthma NOS w (ac) exac', 
              '4941: Bronchiectasis w ac exac', '4957: "ventilation" pneumonit', 
              '496: Chr airway obstruct NEC']
data['copd'] = np.where(data.icd9_codes.str.contains('|'.join(copd_codes)), 1, 0)

liver_codes = ['570: Acute necrosis of liver', '5715: Cirrhosis of liver NOS']
data['liver_disease'] = np.where(data.icd9_codes.str.contains('|'.join(liver_codes)), 1, 0)

heart_codes = []
heart_icd_codes = all_icd_codes[all_icd_codes.shortcode.str.contains("410|427|428")]
for i in heart_icd_codes.index:
    heart_codes.append(heart_icd_codes.longcode[i] + ": " + heart_icd_codes.name[i])
print(heart_codes)
data['heart_disease'] = np.where(data.icd9_codes.str.contains('|'.join(heart_codes)), 1, 0)
# Out:
# ['42731: Atrial fibrillation', '4280: CHF NOS', '41071: Subendo infarct, initial', '41021: AMI inferolateral, init', '42821: Ac systolic hrt failure', '42781: Sinoatrial node dysfunct', '4271: Parox ventric tachycard', '41051: AMI lateral NEC, initial', '42741: Ventricular fibrillation', '42789: Cardiac dysrhythmias NEC', '42823: Ac on chr syst hrt fail', '42820: Systolic hrt failure NOS', '42830: Diastolc hrt failure NOS', '41041: AMI inferior wall, init', '42822: Chr systolic hrt failure', '41092: AMI NOS, subsequent', '4275: Cardiac arrest', '42843: Ac/chr syst/dia hrt fail', '41091: AMI NOS, initial', '42732: Atrial flutter', '41011: AMI anterior wall, init', '41072: Subendo infarct, subseq', '42832: Chr diastolic hrt fail', '42842: Chr syst/diastl hrt fail', '42833: Ac on chr diast hrt fail', '42841: Ac syst/diastol hrt fail', '41032: AMI inferopost, subseq', '42840: Syst/diast hrt fail NOS', '42831: Ac diastolic hrt failure', '41081: AMI NEC, initial', '4270: Parox atrial tachycardia', '41001: AMI anterolateral, init', '41031: AMI inferopost, initial', '4272: Parox tachycardia NOS', '41090: AMI NOS, unspecified', '42769: Premature beats NEC', '42761: Atrial premature beats']
# /var/folders/k5/t6qrq2v55gxd80p9mdn45x9r8q8tz2/T/ipykernel_22719/3113583476.py:8: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   data['copd'] = np.where(data.icd9_codes.str.contains('|'.join(copd_codes)), 1, 0)

# %%
sorted_codes = all_icd_codes.sort_values('count', ascending=False)
sorted_codes.head(31)
# Out:
#     shortcode longcode                      name count
# 9         293     2930   Delirium d/t other cond  1671
# 67        401     4019          Hypertension NOS   708
# 2         427    42731       Atrial fibrillation   599
# 3         428     4280                   CHF NOS   571
# 23        518    51881  Acute respiratry failure   434
# 134       599     5990  Urin tract infection NOS   433
# 15        584     5849  Acute kidney failure NOS   418
# 90        272     2724    Hyperlipidemia NEC/NOS   374
# 30        414    41401  Crnry athrscl natve vssl   356
# 114       250    25000  DMII wo cmp nt st uncntr   310
# 27        995    99592             Severe sepsis   305
# 7         486      486   Pneumonia, organism NOS   273
# 88        244     2449        Hypothyroidism NOS   244
# 235       276     2762                  Acidosis   241
# 13        507     5070    Food/vomit pneumonitis   239
# 26        285     2851   Ac posthemorrhag anemia   235
# 123       285     2859                Anemia NOS   227
# 44        276     2760           Hyperosmolality   227
# 66        530    53081         Esophageal reflux   210
# 83        V58    V5861  Long-term use anticoagul   201
# 18        038     0389            Septicemia NOS   200
# 1         584     5845  Ac kidny fail, tubr necr   200
# 142       311      311   Depressive disorder NEC   197
# 16        403    40390  Hy kid NOS w cr kid I-IV   195
# 157       276     2761             Hyposmolality   180
# 24        785    78552              Septic shock   177
# 55        585     5859    Chronic kidney dis NOS   177
# 69        496      496   Chr airway obstruct NEC   175
# 70        511     5119      Pleural effusion NOS   174
# 25        287     2875      Thrombocytopenia NOS   160
# 299       412      412    Old myocardial infarct   152

# %% [markdown]
# # Formatting the datasets for use in exploratory, ml and causal analysis

# %%
from collections import Counter

# %%
def label_drug_name(row, frequency):
    drugs_list = row['drugs'].lower().split('\n')
    drugs_list_counter = Counter(drugs_list)
    if (frequency == 0):
        value, count = drugs_list_counter.most_common()[0]
    elif (frequency == 1):
        if (len(drugs_list_counter) > 1):
            value, count = drugs_list_counter.most_common()[1]
        else:
            value = 'NA'
    else:
        raise AttributeError("Frequency must be 0 or 1")
    return value

# %%
def label_drug_type(row):
    if "no drug" in row['drug_1']:
        return 'ND'
    if "haloperidol" in row['drug_1']:
        return 'HL'
    if "ziprasidone" in row['drug_1']:
        return 'ZP'
    return 'OD'

# %%
def label_timelength(row):
    if (pd.isna(row['drugstarttime'])):
        return -1
    
    if (pd.notna(row["deathtime"])):
        final_time = row["deathtime"]
    else:
        final_time = row["dischtime"]
            
    length = pd.Timedelta(pd.to_datetime(final_time) - pd.to_datetime(row["drugstarttime"])).total_seconds()
    length_in_days = round(length/ 86400.0) # in days
    return length_in_days

# %%
def label_age(row):
    if row['age'] > 299:
        return 90
    else:
        return row['age']
    return row['age']

# %%
# def label_sex(row):
#     if row['gender'] == 'F':
#         return 1
#     else:
#         return 0
#     return 1

# %%
# https://grants.nih.gov/grants/guide/notice-files/not-od-15-089.html
def label_ethnicity(row):
    if (('WHITE' in row["ethnicity"].upper()) | ('EASTERN' in row["ethnicity"].upper())):
        return 1
    if ('BLACK' in row["ethnicity"].upper()):
        return 2
    if (('HISPANIC' in row["ethnicity"].upper()) | ('LATINO' in row["ethnicity"].upper())):
        return 3
    if ('ASIAN' in row["ethnicity"].upper()):
        return 4
    if (('AMERICAN' in row["ethnicity"].upper()) | ('ALASKA' in row["ethnicity"].upper())):
        return 5
    return 0

# %%
def label_time_to_mechvent(row):
    if ((isinstance(row["mechvent_duration_hours"], int)) | ((isinstance(row["mechvent_duration_hours"], float)))):
        return float(row["mechvent_duration_hours"])
    else:
        if ("," in row["mechvent_duration_hours"]):
            return float(max(row["mechvent_duration_hours"].split(",")))
        else:
            return float(row["mechvent_duration_hours"])
    return 0

# %%
import datetime

def label_time_to_mechvent(row):
    if pd.isna(row['mechvent_starttime']):
        return -1.0
    else:
        datetimeFormat = '%Y-%m-%d %H:%M:%S'
        date1 = row['mechvent_starttime']
        date2 = row['admittime']
        diff = datetime.datetime.strptime(date1, datetimeFormat) - datetime.datetime.strptime(date2, datetimeFormat)
        return (diff.total_seconds() / 86400)
    return -1.0

# %%
def label_mechvent(row):
    if row['mechvent_count'] == 0:
        return 0
    else:
        return 1
    return 0

# %%
def label_mechvent_hours(row):
    if ((isinstance(row["mechvent_duration_hours"], int)) | ((isinstance(row["mechvent_duration_hours"], float)))):
        return float(row["mechvent_duration_hours"])
    else:
        if ("," in row["mechvent_duration_hours"]):
            return float(max(row["mechvent_duration_hours"].split(",")))
        else:
            return float(row["mechvent_duration_hours"])
    return 0

# %%
def label_death_type(row):
    if (pd.isna(row['deathtime']) or pd.isna(row['deathtime'])):
        return -1
        
    datetimeFormat = '%Y-%m-%d %H:%M:%S'
    date1 = row['deathtime']
    date2 = row['dischtime']
    diff = datetime.datetime.strptime(date1, datetimeFormat) - datetime.datetime.strptime(date2, datetimeFormat)
    days = (diff.total_seconds() / 86400)
    if (days <= 30):
        return 1
    elif ((days > 30) & (days <= 90)):
        return 2
    elif ((days > 90) & (days <= 366)):
        return 3
    else:
        return 4
    return 0

# %%
data['drug_1'] = data.apply(lambda row: label_drug_name(row, 0), axis=1)
data['drug_2'] = data.apply(lambda row: label_drug_name(row, 1), axis=1)
data['drug_group'] = data.apply(lambda row: label_drug_type(row), axis=1)
data['drug_timelength'] = data.apply(lambda row: label_timelength(row), axis=1)
data['age'] = data.apply(lambda row: label_age(row), axis=1)
data['race'] = data.apply(lambda row: label_ethnicity(row), axis=1)
data['time_to_mechvent'] = data.apply(lambda row: label_time_to_mechvent(row), axis=1)
data['mechvent'] = data.apply(lambda row: label_mechvent(row), axis=1)
data['time_in_mechvent'] = data.apply(lambda row: label_mechvent_hours(row), axis=1)
data['death_timeline'] = data.apply(lambda row: label_death_type(row), axis=1)

# %%
data.shape
# Out:
# (1671, 43)

# %%
data.sample(3)
# Out:
#       subject_id sex    age ethnicity  hadm_id  icustay_id  los_days  \
# 1591       93991   F  88.70     WHITE   125524      267747    1.1474
# 1315       76479   F  52.20     WHITE   157132      229374    2.6916
# 1465       85842   M  67.45     WHITE   130730      200575    1.3992
#
#                                              icd9_codes  sofa  apsiii  \
# 1591  85206: Subarach hem-coma NOS\n2930: Delirium d...     1      40
# 1315  5551: Reg enteritis, lg intest\n452: Portal ve...     1      38
# 1465  5770: Acute pancreatitis\n42833: Ac on chr dia...     5      41
#
#      mechvent_starttime  mechvent_count mechvent_duration_hours  \
# 1591                NaN               0                     NaN
# 1315                NaN               0                     NaN
# 1465                NaN               0                     NaN
#
#                                                   drugs  \
# 1591                 Prochlorperazine\nProchlorperazine
# 1315  Prochlorperazine\nProchlorperazine\nProchlorpe...
# 1465  Haloperidol\nOlanzapine (Disintegrating Tablet...
#
#       drug_categories_distinct_count                drug_categories  surgery  \
# 1591                               1               PROCHLORPERAZINE        0
# 1315                               2  HALOPERIDOL\nPROCHLORPERAZINE        0
# 1465                               2        HALOPERIDOL\nOLANZAPINE        0
#
#       pneumonia  sepsis  dementia  alzheimers  depression  anxiety  \
# 1591          0       0         0           0           0        0
# 1315          0       0         0           0           0        0
# 1465          0       0         0           0           1        0
#
#       death_hosp  death_one_year        drugstarttime            admittime  \
# 1591           0               0  2144-07-01 15:24:26  2144-07-01 15:23:00
# 1315           0               0  2176-09-20 19:37:48  2176-09-01 11:37:00
# 1465           0               1  2139-01-08 15:46:46  2139-01-08 15:45:00
#
#                 dischtime            deathtime  met_acidosis  airway_obs  \
# 1591  2144-07-06 15:22:00                  NaN             0           0
# 1315  2176-10-09 15:03:00                  NaN             0           0
# 1465  2139-01-20 14:40:00  2139-05-16 00:00:00             0           0
#
#       copd  liver_disease  heart_disease            drug_1  \
# 1591     0              0              0  prochlorperazine
# 1315     0              0              1  prochlorperazine
# 1465     0              0              1       haloperidol
#
#                                   drug_2 drug_group  drug_timelength  race  \
# 1591                                  NA         OD                5     1
# 1315                         haloperidol         OD               19     1
# 1465  olanzapine (disintegrating tablet)         HL              127     1
#
#       time_to_mechvent  mechvent  time_in_mechvent  death_timeline
# 1591              -1.0         0               NaN              -1
# 1315              -1.0         0               NaN              -1
# 1465              -1.0         0               NaN               3

# %%
data.columns
# Out:
# Index(['subject_id', 'sex', 'age', 'ethnicity', 'hadm_id', 'icustay_id',
#        'los_days', 'icd9_codes', 'sofa', 'apsiii', 'mechvent_starttime',
#        'mechvent_count', 'mechvent_duration_hours', 'drugs',
#        'drug_categories_distinct_count', 'drug_categories', 'surgery',
#        'pneumonia', 'sepsis', 'dementia', 'alzheimers', 'depression',
#        'anxiety', 'death_hosp', 'death_one_year', 'drugstarttime', 'admittime',
#        'dischtime', 'deathtime', 'met_acidosis', 'airway_obs', 'copd',
#        'liver_disease', 'heart_disease', 'drug_1', 'drug_2', 'drug_group',
#        'drug_timelength', 'race', 'time_to_mechvent', 'mechvent',
#        'time_in_mechvent', 'death_timeline'],
#       dtype='object')

# %%
# dropping: 
# 'ethnicity', 'mechvent_starttime','drugstarttime', 'admittime', 'dischtime', 
# 'deathtime', 'mechvent_duration_hours', 'drugs', 'drug_categories', 'death_one_year', 'drug_1', 'drug_2'
data = data[['subject_id', 'hadm_id', 'icustay_id', 'sex', 'age', 'race', 'icd9_codes',
             'sofa', 'apsiii', 'surgery', 'pneumonia', 'sepsis', 'dementia', 'alzheimers', 'depression', 
             'anxiety', 'met_acidosis', 'airway_obs', 'copd', 'liver_disease', 'heart_disease', 
             'mechvent', 'mechvent_count', 'drug_group', 'drug_categories_distinct_count', 'drug_timelength', 
             'death_hosp', 'death_timeline', 'los_days', 'time_to_mechvent', 'time_in_mechvent']]

# %%
data = data.astype({"drug_group": 'category'})

# %%
data.shape
# Out:
# (1671, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subject_id                      1671 non-null   int64
#  1   hadm_id                         1671 non-null   int64
#  2   icustay_id                      1671 non-null   int64
#  3   sex                             1671 non-null   category
#  4   age                             1671 non-null   float64
#  5   race                            1671 non-null   int64
#  6   icd9_codes                      1671 non-null   object
#  7   sofa                            1671 non-null   int64
#  8   apsiii                          1671 non-null   int64
#  9   surgery                         1671 non-null   int64
#  10  pneumonia                       1671 non-null   int64
#  11  sepsis                          1671 non-null   int64
#  12  dementia                        1671 non-null   int64
#  13  alzheimers                      1671 non-null   int64
#  14  depression                      1671 non-null   int64
#  15  anxiety                         1671 non-null   int64
#  16  met_acidosis                    1671 non-null   int64
#  17  airway_obs                      1671 non-null   int64
#  18  copd                            1671 non-null   int64
#  19  liver_disease                   1671 non-null   int64
#  20  heart_disease                   1671 non-null   int64
#  21  mechvent                        1671 non-null   int64
#  22  mechvent_count                  1671 non-null   int64
#  23  drug_group                      1671 non-null   category
#  24  drug_categories_distinct_count  1671 non-null   int64
#  25  drug_timelength                 1671 non-null   int64
#  26  death_hosp                      1671 non-null   int64
#  27  death_timeline                  1671 non-null   int64
#  28  los_days                        1665 non-null   float64
#  29  time_to_mechvent                1671 non-null   float64
#  30  time_in_mechvent                854 non-null    float64
# dtypes: category(2), float64(4), int64(24), object(1)
# memory usage: 382.2+ KB

# %%
data.sample(5)
# Out:
#       subject_id  hadm_id  icustay_id sex    age  race  \
# 1614       96015   166722      293747   F  74.05     1
# 1505       89065   100845      286443   F  83.31     1
# 835        46217   161623      236823   F  82.60     2
# 1343       77308   113465      207055   M  67.13     1
# 1369       79909   175576      219892   M  87.46     3
#
#                                              icd9_codes  sofa  apsiii  \
# 1614  1970: Secondary malig neo lung\n4821: Pseudomo...     4      34
# 1505  78659: Chest pain NEC\n42842: Chr syst/diastl ...     1      38
# 835   99811: Hemorrhage complic proc\n5570: Ac vasc ...    11      62
# 1343  2536: Neurohypophysis dis NEC\n1983: Sec mal n...     2      21
# 1369  0389: Septicemia NOS\n78552: Septic shock\n599...     1      49
#
#       surgery  pneumonia  sepsis  dementia  alzheimers  depression  anxiety  \
# 1614        1          1       0         0           0           0        0
# 1505        0          0       0         0           0           0        0
# 835         1          0       0         0           0           0        0
# 1343        0          0       0         0           0           0        0
# 1369        0          0       1         0           1           0        0
#
#       met_acidosis  airway_obs  copd  liver_disease  heart_disease  mechvent  \
# 1614             0           0     0              0              1         1
# 1505             0           0     0              0              1         0
# 835              0           0     0              0              0         1
# 1343             0           0     0              0              0         0
# 1369             0           0     0              0              1         0
#
#       mechvent_count drug_group  drug_categories_distinct_count  \
# 1614               3         HL                               3
# 1505               0         HL                               1
# 835                1         ND                               0
# 1343               0         OD                               1
# 1369               0         OD                               1
#
#       drug_timelength  death_hosp  death_timeline  los_days  time_to_mechvent  \
# 1614              253           0               3   15.4564          1.937500
# 1505                2           0              -1    1.1076         -1.000000
# 835                12           0              -1    8.1460          0.093056
# 1343               56           0               2    1.0113         -1.000000
# 1369              741           0               4    1.2984         -1.000000
#
#       time_in_mechvent
# 1614          2.000000
# 1505               NaN
# 835         161.083333
# 1343               NaN
# 1369               NaN

# %%
# count the na s and fix it
data.isna().sum()
# Out:
# subject_id                          0
# hadm_id                             0
# icustay_id                          0
# sex                                 0
# age                                 0
# race                                0
# icd9_codes                          0
# sofa                                0
# apsiii                              0
# surgery                             0
# pneumonia                           0
# sepsis                              0
# dementia                            0
# alzheimers                          0
# depression                          0
# anxiety                             0
# met_acidosis                        0
# airway_obs                          0
# copd                                0
# liver_disease                       0
# heart_disease                       0
# mechvent                            0
# mechvent_count                      0
# drug_group                          0
# drug_categories_distinct_count      0
# drug_timelength                     0
# death_hosp                          0
# death_timeline                      0
# los_days                            6
# time_to_mechvent                    0
# time_in_mechvent                  817
# dtype: int64

# %%
data.los_days = data.los_days.fillna(-1)
data.time_in_mechvent = data.time_in_mechvent.fillna(-1)
data.isna().sum()
# Out:
# subject_id                        0
# hadm_id                           0
# icustay_id                        0
# sex                               0
# age                               0
# race                              0
# icd9_codes                        0
# sofa                              0
# apsiii                            0
# surgery                           0
# pneumonia                         0
# sepsis                            0
# dementia                          0
# alzheimers                        0
# depression                        0
# anxiety                           0
# met_acidosis                      0
# airway_obs                        0
# copd                              0
# liver_disease                     0
# heart_disease                     0
# mechvent                          0
# mechvent_count                    0
# drug_group                        0
# drug_categories_distinct_count    0
# drug_timelength                   0
# death_hosp                        0
# death_timeline                    0
# los_days                          0
# time_to_mechvent                  0
# time_in_mechvent                  0
# dtype: int64

# %%
data.to_csv('delirium_data_cleaned.csv', header=True, index=False)
sorted_codes.to_csv('delirium_data_icd_codes.csv', header=True, index=False)
